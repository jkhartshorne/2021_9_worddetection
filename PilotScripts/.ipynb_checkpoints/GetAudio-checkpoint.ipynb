# %% [markdown]
# I pre-downloaded a lot of files so that you don't need to be constantly querying the database. Here's what the notebook does with these files:
#
# (1) It goes through all the transcripts in a specified age range (currently 6 to 72 months) and only grabs those that have associated audio/video with timestamps.
#
# (2) From those transcripts, it builds a map from word to transcript ID so you can easily get all the transcripts that contain whatever word you are looking for. You can also do this with the API, but it involves a lot of querying.
#
# (4) It maps transcript IDs to file names and likely URLs to give you you most of the info you need to go retrieve the audio file associated with a particular transcript. You can sub in wav for xml in the file names, and if that doesn't work try mp3 or mp4. The only challenge is that there is frequently a 0wav directory buried at some level in the directory structure that contains wavs. Finding the wav files in this case might involve some manual oversight.

# %%
# imports
import pandas as pd
import sys
import numpy as np
import nltk
import glob

# %%
# Read through each csv file of utterances from the corpora
# that we've previously confirmed have media files.

# I'm using pre-downloaded csvs to avoid too many api calls
csvfiles = glob.glob("csv-files-EngNA-media/[A-Z]*.csv")

# keep track of which words are in which utterances
# faster than querying the database
word2utt = {}

# keep track of which utterances have start and stop times
# these are the only ones we care about right now
timestamps = {}

# keep track of all words that are used for frequency counting
# we only want to look at the highest frequency words
yesprint = 0
wordlist = []
for c in csvfiles:
    
    # print out every 10th corpus to reduce verbosity of output
    #if yesprint % 10 == 0:
    print(c)
    #yesprint +=1 

    # read in the csv file
    child = pd.read_csv(c)
    
    # get kid age, start and stop times
    child = child.astype({"target_child_age": float})
    child = child.astype({"media_start": float})
    child = child.astype({"media_end": float})

  
    # this stores utterances from kids between 6 and 72 months
    # who have transcripts with start and stop times
    newchild = child.loc[(child["speaker_role"] == "Target_Child") & 
              (child["target_child_age"] >= 6) &
              (child["target_child_age"] <= 72) &
              (child["media_start"] > 0),
                         ["id", "transcript_id", "media_start", "media_end", "gloss", "target_child_sex","target_child_age"]]
    
    # compile complete record into alldata
    try:
        alldata = alldata.append(newchild)
    except Exception as noalldata:
        alldata = newchild
    
    thedata = list(newchild.itertuples(index=False, name=None))
    
    # first map every word to all the utterances it appears in (word2utt)
    # then map each utterance ID to its transcript ID, timestamps, gloss, 
    # and corpus name (timestamps)
    for line in thedata:
        if type(line[4]) == str:
            for w in line[4].split():
                wordlist.append(w)
                if w in word2utt:
                    word2utt[w].append(line[0])
                else:
                    word2utt[w] = [line[0]]
            timestamps[line[0]] = [line[1], line[2], line[3], line[4], c]
            
# Note that Sprott corpus as exported doesn't have ages for kids, though those are available
# Note also that childes-py does not have access to MOST of the kids in CHILDES.
# Out:
# csv-files-EngNA-media/NewmanRatner.csv
# csv-files-EngNA-media/Goad.csv
# csv-files-EngNA-media/Peters.csv
# csv-files-EngNA-media/Gleason.csv
# csv-files-EngNA-media/PaidoEnglish.csv
# csv-files-EngNA-media/Brent.csv
# csv-files-EngNA-media/Providence.csv
# csv-files-EngNA-media/Sprott.csv
# csv-files-EngNA-media/Sachs.csv
# csv-files-EngNA-media/Bloom.csv
# csv-files-EngNA-media/Bernstein.csv
# csv-files-EngNA-media/Soderstrom.csv
# csv-files-EngNA-media/EllisWeismer.csv
# csv-files-EngNA-media/POLER.csv
# csv-files-EngNA-media/Rollins.csv
# csv-files-EngNA-media/McCune.csv
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (21) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# csv-files-EngNA-media/Snow.csv
# csv-files-EngNA-media/Menn.csv
# csv-files-EngNA-media/VanHouten.csv
# csv-files-EngNA-media/McMillan.csv
# csv-files-EngNA-media/Nelson.csv
# csv-files-EngNA-media/Davis.csv
# csv-files-EngNA-media/Weist.csv
# csv-files-EngNA-media/Braunwald.csv
# csv-files-EngNA-media/MacWhinney.csv
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (3,12) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
# example: print the data for utt 2703191
print(timestamps[2703191])

# example: print the first 10 utts that have "doggy"
print(word2utt["doggy"][0:10])
# Out:
# [10177, 820.761, 823.738, 'yyy ride yyy doggy back', 'csv-files-EngNA-media/NewmanRatner.csv']
# [2686897, 2687332, 2687457, 2687619, 2694910, 2696457, 2703191, 2703343, 2720479, 2786680]

# %%
# Here's a quick example of how to use the python wrapper
# for the R interface to childesdb in case you'd like to 
# use this later to get files

# https://github.com/langcog/childespy

#import childespy
#utterances = childespy.get_utterances(corpus="ENNI")
#utterances.to_csv("ENNI.csv")

#import childespy
#phontrans = childespy.get_transcripts(corpus = "MacWhinney")
#phontrans.to_csv("moretranscripts.csv")

# %%
# map corpus name to collection so you can get URL for audio
# only worry about the corpora we know have media,
# using a manually curated list of EngNA corpora with media.
corp2url = {}

import csv
with open('corpora-EngNA-media.txt', newline='') as csvfile:
    csvfile.readline()
    treader = csv.reader(csvfile, delimiter='|', quotechar='"')
    for row in treader:
        corp2url[row[1]] = "https://media.talkbank.org/" + row[0].lower() + "/"

# %%
# map transcript IDs to file names since we need the file
# names to retrieve the audio
# getting this from a pre-downloaded file of EngNA transcripts to avoid 
# api calls

trans2file = {}
import csv
with open('transcripts.csv', newline='') as csvfile:
    csvfile.readline()
    treader = csv.reader(csvfile, delimiter=',', quotechar='"')
    for row in treader:
        if row[2] in corp2url:
            urlstart = corp2url[row[2]]
            fileurl = urlstart + "/" + row[5]
            trans2file[int(row[1])] = (urlstart + row[5], row[7])

# %%
# now get a list of audio and video files that have timestamped 
# transcriptsion using the timestamps dictionary

audio2get = {}
missing = {}
for t,v in timestamps.items():
    audio2get[ trans2file[v[0]][0] ] = 1


print(len(audio2get.keys()))
# Out:
# 2856

# %% [markdown]
# ### Next step: Get the audio files
#
# * Determining mp3 vs. wav vs. mp4 will require either parsing the main webpage for the media for that corpus or just trying both and seeing what works. Recall that there is often a 0wav directory with wav files somewhere in corpora that seem to have only mp3.
# * I use curl or wget in a shell to get the audio, but urllib in python works fine, see below.

# %%
# function to get an audio file

# this lets you bypass weird SSL problem with CHILDES
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# Need for handling mp4s
import ffmpeg
import sox

# some other imports
import urllib.request
import re
import os

# function: takes a url, tries to get the audio file first as
# a wav then as an mp3. Returns the file name if successful
# and return "failure" if unsuccessful
# Note: this only works for childes and not phonbank.
# Need to fancy up the regex below.
def get_the_audiofile(afilename, verbose=False):
    
    thefile = re.sub("xml", "wav", afilename)
    if thefile=="https://media.talkbank.org/childes/Eng-NA/MacWhinney/021001a.wav":
        #this wav file is mislabeled
        thefile = "https://media.talkbank.org/childes/Eng-NA/MacWhinney/021001.wav"
    
    outputfile = re.sub("Frogs/", "splitme", thefile)
    outputfile = re.sub("Eng-NA/", "splitme", outputfile)
    outputfile = re.sub("Clinical-MOR/", "splitme", outputfile)
    
    outputfile = re.sub("/", "_", outputfile).split("splitme")[1]
    outputfile = "rawfiles/" + outputfile
    # let's not waste time re-downloading files
    if verbose:
        print("checking for " + outputfile)
    if os.path.exists(outputfile):
        if verbose:
            print("file already downloaded")
        return outputfile

    # first try as a wav file

    try:
        if verbose:
            print(thefile, outputfile)
        urllib.request.urlretrieve(thefile, outputfile)
        if verbose: 
            print("DOWNLOAD COMPLETE:", outputfile, "\n\n")
        return outputfile
        
    except Exception as e:
        
            # if that fails, look for the 0wav folder
            if verbose:
                print("ERROR: Could not download wav file {}".format(thefile))
                print("Trying to find the 0wav folder, if any")
            string = thefile.split("/")
            thenewfile = "/".join(string[0:(len(string)-2)] + ["0wav"] + string[(len(string)-2):len(string)])
            if thefile.find("EllisWeismer/TD")>0:
                thenewfile = re.sub("/TD/","/0wav/",thefile)
                string = thenewfile.split("/")
                thenewfile = "/".join(string[0:(len(string)-1)] + ["controls"] + string[(len(string)-1):len(string)])
            if verbose:
                print(thenewfile, outputfile)
            try:
                urllib.request.urlretrieve(thenewfile, outputfile)
                if verbose:
                    print("DOWNLOAD COMPLETE:", outputfile, "\n\n")
                return outputfile

            except Exception as e2:

                    # if that fails, look again for the 0wav folder
                    if verbose:
                        print("ERROR: Could not download wav file {}".format(thenewfile))
                        print("Trying to find the 0wav folder, if any")
                    string = thefile.split("/")
                    thenewfile = "/".join(string[0:(len(string)-1)] + ["0wav"] + string[(len(string)-1):len(string)])
                    if thefile.find("Gleason/Father")>0:
                        # because why, Brian, why?
                        thenewfile = re.sub(".wav","-f.wav",thenewfile)
                    if thefile.find("Gleason/Mother")>0:
                        # because why, Brian, why?
                        thenewfile = re.sub(".wav","-m.wav",thenewfile)
                    if verbose:
                        print(thenewfile, outputfile)
                    try:
                        urllib.request.urlretrieve(thenewfile, outputfile)
                        if verbose:
                            print("DOWNLOAD COMPLETE:", outputfile, "\n\n")
                        return outputfile

                    except Exception as e3:

                            # if that fails, look one last time for the 0wav folder
                            if verbose:
                                print("ERROR: Could not download wav file {}".format(thenewfile))
                                print("Trying to fine the 0wav folder, if any")
                            string = thefile.split("/")
                            thenewfile = "/".join(string[0:(len(string)-3)] + ["0wav"] + string[(len(string)-3):len(string)])
                            if verbose:
                                print(thenewfile, outputfile)
                            try:
                                urllib.request.urlretrieve(thenewfile, outputfile)
                                if verbose:
                                    print("DOWNLOAD COMPLETE:", outputfile, "\n\n")
                                return outputfile

                            except Exception as e4:

                                # if that fails, try as an mp3
                                if verbose:
                                    print("ERROR: Could not download wav file {}".format(thenewfile))
                                    print("Trying to download mp3")
                                thenewfile = re.sub("wav", "mp3", thefile)
                                outputfile = re.sub("wav", "mp3", outputfile)
                                if verbose:
                                    print(thenewfile, outputfile)
                                try:
                                    urllib.request.urlretrieve(thenewfile, outputfile)
                                    if verbose:
                                        print("DOWNLOAD COMPLETE:", outputfile, "\n\n Converting to wav \n\n")
                                    outputfile2 = re.sub("mp3", "wav", outputfile)
                                    tfm = sox.Transformer()
                                    tfm.build_file(outputfile, outputfile2)
                                    return outputfile2

                                except Exception as e5:

                                    # if that fails, try as an mp4
                                    if verbose:
                                        print("ERROR: Could not download mp3 file {}".format(thenewfile))
                                        print("Trying to download mp4")
                                    thenewfile = re.sub("wav", "mp4", thefile)
                                    outputfile = re.sub("mp3", "mp4", outputfile)
                                    if verbose: 
                                        print(thenewfile, outputfile)
                                    try:
                                        urllib.request.urlretrieve(thenewfile, outputfile)
                                        if verbose: 
                                            print("DOWNLOAD COMPLETE:", outputfile, "\n\n Converting mp4 to wav \n\n")
                                        outputfile2 = re.sub("mp4", "wav", outputfile)
                                        ffmpeg.input(outputfile).output(outputfile2).run()
                                        return outputfile2

                                    except Exception as e6:
                                        if verbose:
                                            print("GIVING UP: Could not download mp4 file {}".format(thenewfile))
                                        return "failure"

# %% [markdown]
# Some notes on files.
#
# * EllisWeismer has both TD and language delayed kids. Make sure not to use the language delayed kids.
#
# Unusable 0wav
# * Eng-NA/NewmanRatner has a 0wav for the main files, but not for /Interviews/
# * English-NA/Goad has 0wav but it collapses all the clips into a single file, so not easily usable
# * English-NA/Providence has 0wav folders for two of the kids, but these folders only contain mp3s
#
# No 0wav folders:
# * English-NA/Sachs
# * English-NA/Weist

# %% [markdown]
# ### Step after that: Extracting audio
# Once you've downloaded the audio files, you'll use the data in the timestamps dictionary above to extract the audio clips corresponding to the utterance. I use the unix tools sox or ffmpeg, but there is a nice python wrapper for sox that does this well.

# %%
# parse audiofile
def get_clip(uttdata, uttid, afile, theword, verbose=False):

    tfm = sox.Transformer()
    starttime = uttdata[1]
    stoptime = uttdata[2]
    tfm.trim(starttime, stoptime)
    tfm.convert(16000, 1) 
    newtail = "_" + str(starttime) + "-" + str(stoptime) + ".wav"
    newfile = re.sub(".wav", newtail, afile)
    #newfile = theword + "_" + newfile
    newfile = re.sub("rawfiles/","",newfile)
    tfm.build_file(afile, "parsedfiles/" + newfile)

    if verbose:
        print("New file created:", newfile)
        print("Transcript:", uttdata[3] )
    
    alldata.loc[alldata["id"] == uttid, "file"] = newfile
    
    return True

# %%
# example: getting an audio file from CHILDES
# and extracting relevant portion using timestamps

import random

# pick some random utterance
someutt = random.choice(list(timestamps.keys()))
uttdata = timestamps[someutt]

#print(uttdata)

# look up the associated audio file
audiofile = trans2file[uttdata[0]]
outfilename = get_the_audiofile(audiofile[0])

if outfilename != "failure":
    # creating a new file using timestamps
    get_clip(uttdata, someutt, outfilename, "y")

# %% [markdown]
# Now let's actually download the files we need

# %%
# set words of interest
words = ["baby","daddy","mommy","dad","car"]

# %%
import warnings
warnings.filterwarnings("ignore")

nofind = []
noparse = []

for word in words:
    print("now working on :" + word)
    wordstamps = word2utt[word]
    for someutt in wordstamps:
        uttdata = timestamps[someutt]

        #print(uttdata)

        audiofile = trans2file[uttdata[0]]
        outfilename = get_the_audiofile(audiofile[0])

        if outfilename != "failure":
            # creating a new file using timestamps
            try:
                get_clip(uttdata, someutt, outfilename, word)
            except Exception as parsefail:
                print("Unable to parse "+outfilename)
                noparse = noparse + [someutt]
        else:
            nofind = nofind + [someutt]
# Out:
# output_file: parsedfiles/daddy_NewmanRatner_24_5346GG_938.086-940.687.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_NewmanRatner_24_5623AT_816.434-817.357.wav already exists and will be overwritten on build
# now working on :daddy
# output_file: parsedfiles/daddy_NewmanRatner_24_5623AT_826.938-829.341.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_NewmanRatner_24_7162MB_424.653-426.816.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_NewmanRatner_24_6071WB_641.037-648.03.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_NewmanRatner_24_6071WB_696.932-702.421.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_NewmanRatner_24_7658LT_153.399-155.667.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_NewmanRatner_Interviews_24_5073AC_154.007-157.767.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Goad_Julia_11102_126.594-127.781.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Goad_Julia_11116_185.775-187.389.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Goad_Julia_11116_196.981-198.478.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Goad_Julia_20116_330.315-331.632.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Goad_Julia_11015_121.746-122.764.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Goad_Julia_11102_159.127-160.282.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Goad_Julia_11116_211.531-212.477.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Goad_Julia_11116_230.565-232.071.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Goad_Julia_11116_234.7-235.66.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Goad_Julia_20200_461.905-463.524.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Goad_Julia_20200_463.524-464.766.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Goad_Julia_20027_296.993-298.467.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Goad_Julia_20027_298.467-299.628.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Goad_Julia_20425_993.039-994.844.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Goad_Julia_20411_827.784-829.49.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Goad_Julia_20411_829.49-831.672.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Goad_Julia_20200_478.618-479.534.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Goad_Julia_20510_1087.051-1088.949.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Goad_Julia_20116_408.891-410.397.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Goad_Julia_10814_1836.3-1837.809.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Goad_Julia_21011_2790.208-2792.077.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Goad_Julia_20411_919.738-921.432.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Goad_Julia_20510_1171.987-1173.043.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Goad_Julia_20828_2074.106-2075.929.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Goad_Julia_21011_3059.036-3061.509.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Goad_Julia_30221_5112.356-5113.72.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Goad_Sonya_20206_1254.654-1256.835.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Goad_Sonya_20206_1517.792-1521.471.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Goad_Sonya_20422_2629.478-2630.463.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Goad_Sonya_20422_2632.694-2634.219.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Goad_Sonya_21007_4510.522-4512.216.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Goad_Sonya_20422_2705.262-2706.927.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Gleason_Dinner_laurel_653.149-656.547.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Gleason_Dinner_laurel_727.029-728.863.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Gleason_Dinner_laurel_748.129-750.145.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Gleason_Dinner_laurel_751.845-759.995.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Gleason_Dinner_laurel_751.845-759.995.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Gleason_Dinner_laurel_909.422-917.56.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Gleason_Dinner_katie_1052.342-1053.307.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Gleason_Dinner_katie_1235.432-1238.439.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Gleason_Dinner_katie_1369.709-1370.94.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Gleason_Dinner_katie_1449.1-1450.267.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Gleason_Dinner_katie_1450.267-1453.553.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Gleason_Father_susan_1103.172-1108.989.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Gleason_Father_susan_1436.384-1439.24.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Gleason_Father_helen_676.197-681.193.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Gleason_Mother_helen_398.104-398.79.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Gleason_Mother_helen_557.904-560.237.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Alex_020117_2255.165-2256.436.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Ethan_001121_2480.518-2483.078.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Ethan_010201_1470.511-1474.896.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Ethan_010117_1310.15-1311.188.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Ethan_010117_1322.945-1324.743.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Ethan_010117_1329.528-1330.576.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Ethan_010426_33.435-38.431.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Ethan_010726_2195.656-2201.916.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Ethan_010228_1112.621-1116.585.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Ethan_010228_1118.505-1124.405.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Ethan_010228_1140.075-1141.41.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Ethan_010228_1238.131-1246.63.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Ethan_010228_1246.631-1248.836.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Ethan_010228_1246.631-1248.836.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Ethan_010117_3085.29-3086.545.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Ethan_010117_3091.431-3092.548.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Ethan_010820_2907.058-2913.72.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Ethan_010726_3673.77-3675.178.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Ethan_010726_3675.178-3679.241.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Ethan_010726_3679.241-3682.643.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Ethan_010726_3682.643-3683.84.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Ethan_010726_3683.84-3685.113.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Ethan_010726_3685.113-3687.905.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Ethan_010228_2339.481-2345.986.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Ethan_010726_3721.703-3724.238.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Ethan_010411_1779.166-1782.195.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Ethan_010620_1608.768-1611.035.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Ethan_010517_3610.77-3614.931.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Ethan_010315_3223.843-3226.158.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Ethan_010620_2243.581-2246.428.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Ethan_010804_3636.943-3641.791.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Ethan_010400_1939.32-1943.321.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Ethan_010218_3670.011-3674.033.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Ethan_010218_3674.033-3675.248.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Ethan_010218_3677.908-3682.481.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Ethan_010218_3677.908-3682.481.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Ethan_010218_3682.481-3683.616.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Ethan_010218_3683.616-3686.706.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Ethan_011023_3319.17-3322.82.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Ethan_011023_3322.82-3324.723.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Ethan_020025_2452.501-2455.863.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_010102_2167.723-2171.723.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_010102_2512.94-2514.788.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_010213_2233.146-2234.488.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_010213_2236.306-2237.756.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_010213_2239.138-2240.23.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_010213_2675.6-2676.741.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_010213_2678.808-2679.865.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_010213_2680.426-2682.165.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Ethan_021101_1624.441-1626.558.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Ethan_021101_1631.15-1633.18.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Ethan_020810_2243.703-2246.638.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_010423_67.758-69.35.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_010423_69.351-72.045.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_010423_391.84-392.7.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_010508_322.796-323.69.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_010508_324.625-325.621.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_010508_351.056-351.845.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_010508_356.046-356.8.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_010508_383.05-383.853.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_010508_387.301-388.09.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_010508_388.091-390.73.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_010521_891.725-892.917.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_010508_607.561-609.261.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_010508_649.37-651.593.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_010521_948.532-952.4.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_010521_953.295-954.232.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_010508_668.765-669.4.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_010508_700.655-703.233.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_010508_718.341-719.355.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_010508_723.481-724.2.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_010508_733.031-736.987.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_010719_289.048-290.095.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_010423_2060.594-2062.035.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_010326_624.226-625.09.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_010521_2042.293-2044.032.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_010701_1538.046-1540.105.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_010521_2162.312-2169.053.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_010521_2170.7-2172.502.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_010508_2596.19-2605.85.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_010508_2650.776-2651.593.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_010508_2708.286-2709.855.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_010228_2610.001-2610.851.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_010521_2813.293-2815.227.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_010701_2578.94-2579.576.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Ethan_020907_3272.165-3275.107.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_010701_2890.92-2892.188.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_010701_3608.76-3610.431.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_010701_3778.435-3779.42.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_011022_741.14-746.051.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_010719_3012.593-3017.015.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_010814_1537.248-1539.471.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_010814_1539.371-1541.375.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_010814_1541.375-1543.518.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_010814_1546.345-1549.641.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_010814_1553.37-1559.113.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_010719_3085.481-3087.77.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_020023_141.775-143.946.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Ethan_021005_2595.717-2598.567.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_010814_2535.251-2540.48.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_010814_2535.251-2540.48.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_010814_2540.48-2542.19.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_010814_2552.528-2555.571.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_010611_1449.992-1451.06.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_011107_515.895-517.86.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_010611_1703.898-1705.228.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_010117_1886.791-1888.033.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_010117_1890.573-1891.873.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_010117_1894.015-1895.221.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_010117_1898.04-1899.181.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_010323_680.971-684.053.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_010323_684.055-685.455.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_020101_2039.458-2044.453.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_020023_2257.853-2258.83.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Ethan_020611_3439.076-3442.665.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Ethan_020611_3439.076-3442.665.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_020023_2482.29-2484.35.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_020023_2496.811-2498.651.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_020023_2500.316-2502.843.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_020215b_364.483-365.728.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_020023_2725.168-2727.583.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_020115_1552.348-1557.2.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_020215b_808.511-814.51.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_010618_2642.905-2644.465.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_010618_2645.776-2647.185.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_010323_2140.765-2141.56.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_020201_1041.829-1050.13.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_020108_2630.088-2633.076.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_010618_3019.21-3023.21.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_020201_1270.77-1272.858.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_020215b_1293.948-1300.02.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_020215b_1319.896-1324.715.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_020215b_1364.346-1370.288.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_020215a_961.053-967.101.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_020215a_973.968-977.546.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_020215b_1529.506-1533.9.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_010618_3402.198-3405.311.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_010618_3413.125-3414.746.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_010618_3419.82-3422.625.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_010323_3141.06-3142.285.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_020201_1640.375-1642.896.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_020215a_1311.058-1324.861.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_020123_1948.151-1950.046.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_020123_1950.046-1952.111.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_020123_1966.308-1970.375.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_010323_3322.768-3323.828.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_020227_868.713-870.376.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_020227_873.518-876.758.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_020227_1396.9-1409.45.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_020227_1410.288-1413.086.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_020227_1528.71-1529.925.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_020227_1532.06-1533.165.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_020227_1534.238-1536.081.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_020227_1536.95-1538.291.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_020227_1539.578-1548.383.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_011009_182.321-184.895.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_020506_1854.898-1858.921.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_020506_2527.705-2532.195.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_020506_2533.64-2537.975.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_020506_2533.64-2537.975.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_020011_799.05-803.71.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_020506_2802.35-2803.766.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_020227_2495.955-2497.151.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_020227_2498.966-2503.531.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_020227_2505.321-2506.38.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_020201_3638.105-3642.343.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_020506_2924.608-2925.651.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_020227_2593.72-2595.345.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_020518_978.513-982.438.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_020317_486.028-491.58.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_011009_1069.616-1078.32.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_011009_1082.055-1088.898.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_011009_1114.181-1119.608.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_020700_654.337-667.877.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_020612_1674.361-1677.251.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_020700_736.048-744.272.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_020700_744.272-747.797.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_020317_1321.33-1334.452.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_020317_1338.388-1343.562.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_020612_1852.301-1855.378.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_020612_1855.378-1857.28.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_020612_1859.94-1865.86.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_020305_2607.878-2609.815.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_020317_2143.57-2150.633.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_020612_2877.3-2878.743.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_011009_2586.688-2588.845.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_020716_168.578-181.215.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_020317_2812.258-2817.167.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_020317_2910.265-2914.65.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_020317_2930.762-2934.5.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_020402_2277.56-2281.432.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_020402_2289.897-2292.692.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_011009_3020.415-3024.926.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_011009_3027.225-3028.16.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_011009_3029.391-3031.12.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_011009_3032.481-3035.126.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_020604_3595.053-3600.243.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_020604_3595.053-3600.243.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_020604_3605.708-3610.185.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_020716_1341.263-1357.151.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_020402_3077.703-3080.833.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_020402_3080.833-3083.898.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_030010_395.627-399.745.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_020716_2291.42-2292.856.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_020806_2217.676-2229.325.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_020716_2330.291-2332.823.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_020813_2567.516-2571.775.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_020813_2567.516-2571.775.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_020716_2637.643-2643.591.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_020716_2637.643-2643.591.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_020716_2654.523-2664.73.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_030121_451.763-453.313.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_020716_2991.153-2997.926.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_030121_510.617-515.387.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_030010_1396.84-1400.448.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_030010_1569.532-1574.83.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_020806_3531.093-3533.718.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_020806_3547.118-3552.701.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_030121_1059.005-1063.173.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_020701_377.86-393.148.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_030121_1122.033-1124.862.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_030025_878.537-881.6.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_030003_552.427-554.727.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_020701_534.74-538.616.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_030025_1461.312-1463.953.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_030420_574.038-575.897.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_030010_2571.39-2573.77.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_030010_2573.77-2576.137.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_030010_2583.888-2588.005.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_030010_2583.888-2588.005.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_030010_2643.188-2647.072.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_021125_936.227-943.678.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_030121_2303.743-2305.147.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_020623_3491.396-3498.85.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_030121_2330.607-2332.165.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_030121_2335.567-2338.307.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_030121_2340.2-2344.453.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_030218_648.122-653.723.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_030218_738.013-741.212.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_030218_741.212-744.34.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_021125_1799.605-1801.517.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_030218_890.862-893.242.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_030218_1116.238-1122.845.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_030218_1127.802-1130.248.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_030927a_898.646-902.495.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_030218_1142.155-1148.9.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_030528_1168.717-1173.325.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_030528_1173.883-1175.558.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_030725_2658.0-2664.515.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_030725_2658.0-2664.515.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_030420_2455.332-2457.53.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_030528_1382.658-1387.391.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_020904_3045.485-3050.635.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_030218_2365.323-2371.363.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_030218_2444.12-2447.977.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_030323_1545.82-1550.723.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_030218_2791.768-2793.383.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_030218_2948.368-2952.987.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_030528_3331.538-3333.42.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_030528_3334.72-3336.015.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_030323_2749.447-2750.995.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_030323_3448.477-3454.402.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_030323_3466.92-3470.345.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Naima_010502_2151.458-2155.18.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_040002_455.135-458.486.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Lily_040002_458.486-460.113.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Naima_010808_1314.16-1316.103.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Naima_010910_1465.953-1468.905.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Naima_010915_1446.121-1450.713.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Naima_010915_1446.121-1450.713.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Naima_010915_1451.913-1459.051.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Naima_010808_3229.555-3234.61.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Naima_010808_3237.648-3240.878.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Naima_010808_3354.653-3358.816.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Naima_010808_3366.876-3370.358.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Naima_011012_11.565-12.78.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Naima_011126_1371.396-1375.635.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Naima_011005_2306.43-2309.31.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Naima_020100_1330.358-1335.648.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Naima_011126_2227.321-2231.416.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Naima_011126_2231.366-2234.298.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Naima_020100_1706.258-1708.183.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Naima_020217_1466.553-1470.091.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Naima_020217_1601.588-1605.16.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Naima_020217_1605.16-1610.8.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Naima_020306_1596.168-1599.941.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Naima_020306_1605.108-1608.173.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Naima_020306_1712.865-1716.59.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Naima_020306_1721.545-1725.185.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Naima_020306_1734.165-1735.811.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Naima_020306_1738.786-1743.856.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Naima_020116_1471.5-1473.455.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Naima_011122_1592.88-1597.72.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Naima_011122_1717.63-1721.06.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Naima_011122_1721.06-1725.765.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Naima_011122_1721.06-1725.765.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Naima_011122_1725.765-1727.385.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Naima_020515_59.065-73.816.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Naima_011122_2091.03-2092.875.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Naima_020411_2014.4-2019.776.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Naima_020411_2027.11-2031.675.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Naima_020411_2033.265-2039.226.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Naima_011122_2277.305-2282.56.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Naima_011122_2277.305-2282.56.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Naima_011122_2277.305-2282.56.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Naima_011122_2277.305-2282.56.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Naima_011122_2277.305-2282.56.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Naima_011122_2277.305-2282.56.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Naima_011122_2366.04-2368.16.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Naima_011122_2412.375-2420.155.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Naima_011122_2439.525-2442.735.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Naima_011122_2439.525-2442.735.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Naima_011122_2442.735-2447.745.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Naima_011122_2442.735-2447.745.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Naima_011122_2442.735-2447.745.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Naima_011122_2447.745-2449.38.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Naima_020217_3390.291-3394.38.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Naima_020217_3394.38-3397.71.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Naima_020217_3398.41-3401.211.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Naima_020124_1498.648-1509.026.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Naima_020124_1498.648-1509.026.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Naima_020124_1509.553-1517.753.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Naima_020124_1509.553-1517.753.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Naima_020515_1490.095-1498.681.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Naima_020515_1498.681-1503.05.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Naima_020124_2359.308-2370.821.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Naima_020427_1095.525-1110.13.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Naima_020424_3569.051-3570.911.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Naima_020519_1980.811-1984.421.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Naima_020713_1097.023-1102.483.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Naima_020923_1059.67-1064.381.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Naima_020923_1064.381-1066.21.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Naima_020923_1070.766-1073.638.wav already exists and will be overwritten on build
# output_file: parsedfiles/daddy_Providence_Naima_021008b_38.405-46.663.wav already exists and will be overwritten on build
# ...
#     hd_video        : 0
#     ISFT            : Lavf58.76.100
#   Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, stereo, s16, 1411 kb/s (default)
#     Metadata:
#       creation_time   : 2015-07-16T21:33:47.000000Z
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 pcm_s16le
# size=  592128kB time=00:57:17.29 bitrate=1411.2kbits/s speed=1.27e+03x
# video:0kB audio:592128kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000013%
# output_file: parsedfiles/car_Sachs_010616_912.441-916.243.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_Sachs_010616_912.441-916.243.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_Sachs_011116_427.391-429.491.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_Sachs_011116_430.926-433.728.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_Sachs_020605_746.02-750.155.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_Sachs_020605_924.333-930.403.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_Sachs_030327_1449.409-1453.544.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_Bloom_Peter_020118_1965.352-1984.405.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_Bloom_Peter_020213_2959.171-2966.085.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_Bloom_Peter_020100_4135.272-4168.713.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_Bloom_Peter_020118_5410.78-5415.854.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_Bloom_Peter_011117_6366.41-6372.254.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_Bloom_Peter_020118_5516.068-5525.803.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_Bloom_Peter_020118_5516.068-5525.803.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_Bloom_Peter_020118_5516.068-5525.803.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_Bloom_Peter_020100_4967.033-4977.253.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_Bloom_Peter_020100_4967.033-4977.253.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_Bloom_Peter_020100_5146.093-5155.092.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_Bloom_Peter_020100_5146.093-5155.092.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_Bloom_Peter_020100_5156.579-5166.415.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_Bloom_Peter_020100_5252.173-5253.926.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_Bloom_Peter_020118_6485.866-6517.074.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_Bloom_Peter_020213_6953.762-6959.522.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_Bloom_Peter_020213_7044.403-7056.511.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_Bloom_Peter_020213_7061.619-7070.169.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_Bloom_Peter_020415_162.15-168.178.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_Bloom_Peter_021019_481.059-489.481.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_Bloom_Peter_021019_481.059-489.481.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_Bloom_Peter_011105_5680.124-5682.243.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_Bloom_Peter_011011_8528.63-8542.738.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_Bloom_Peter_011011_8528.63-8542.738.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_Bloom_Peter_011011_8528.63-8542.738.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_Bloom_Peter_020915_3560.108-3563.713.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_Bloom_Peter_030120_2697.935-2702.112.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_Bloom_Peter_030120_2697.935-2702.112.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_Bloom_Peter_030120_2697.935-2702.112.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_Bloom_Peter_020100_11497.976-11500.395.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_Bloom_Peter_020100_11509.512-11513.787.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_Bloom_Peter_020100_11509.512-11513.787.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_Bloom_Peter_020100_11528.411-11535.924.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_Bloom_Peter_020812_256.01-273.774.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_Bloom_Peter_020713_12430.852-12434.067.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_EllisWeismer_TD_30ec_12020_850.844-857.218.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_EllisWeismer_TD_30ec_12020_860.132-862.965.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_EllisWeismer_TD_30ec_12020_952.71-955.427.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_EllisWeismer_TD_30ec_12020_965.226-968.836.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_EllisWeismer_TD_30ec_12020_965.226-968.836.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_EllisWeismer_TD_30ec_12077_246.393-251.531.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_EllisWeismer_TD_30pc_12033_224.386-228.101.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_EllisWeismer_TD_54int_22104_741.215-750.282.wav already exists and will be overwritten on build
# ffmpeg version 4.4 Copyright (c) 2000-2021 the FFmpeg developers
#   built with Apple clang version 12.0.5 (clang-1205.0.22.9)
#   configuration: --prefix=/usr/local/Cellar/ffmpeg/4.4_2 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libbluray --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-avresample --enable-videotoolbox
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'rawfiles/Rollins_jp12.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 512
#     compatible_brands: mp42
#     creation_time   : 2015-07-16T05:05:03.000000Z
#     media_type      : 9
#     season_number   : 1
#     episode_sort    : 1
#     hd_video        : 0
#     iTunMOVI        : <?xml version="1.0" encoding="UTF-8"?><!DOCTYPE plist PUBLIC "-//Apple Computer//DTD PLIST 1.0//EN"  "http://www.apple.com/DTDs/PropertyList-1.0.dtd"><plist version="1.0"><dict><key>studio</key><string>studio</string><key>cast</key><array><dict><key>name<
#   Duration: 00:20:29.06, start: 0.000000, bitrate: 667 kb/s
#   Stream #0:0(eng): Video: h264 (Constrained Baseline) (avc1 / 0x31637661), yuv420p, 320x240 [SAR 1:1 DAR 4:3], 534 kb/s, 29.97 fps, 29.97 tbr, 30k tbn, 58 tbc (default)
#     Metadata:
#       creation_time   : 2015-07-16T05:05:03.000000Z
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : h264
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       creation_time   : 2015-07-16T05:05:03.000000Z
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'rawfiles/Rollins_jp12.wav':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 512
#     compatible_brands: mp42
#     iTunMOVI        : <?xml version="1.0" encoding="UTF-8"?><!DOCTYPE plist PUBLIC "-//Apple Computer//DTD PLIST 1.0//EN"  "http://www.apple.com/DTDs/PropertyList-1.0.dtd"><plist version="1.0"><dict><key>studio</key><string>studio</string><key>cast</key><array><dict><key>name<
#     media_type      : 9
#     season_number   : 1
#     episode_sort    : 1
#     hd_video        : 0
#     ISFT            : Lavf58.76.100
#   Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, stereo, s16, 1411 kb/s (default)
#     Metadata:
#       creation_time   : 2015-07-16T05:05:03.000000Z
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 pcm_s16le
# size=  211720kB time=00:20:29.03 bitrate=1411.2kbits/s speed=1.22e+03x
# video:0kB audio:211720kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000036%
# output_file: parsedfiles/car_McCune_Alice_010705_216.481-218.243.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_McCune_Alice_010600_1566.285-1579.268.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_Snow_020518b_3570.5-3574.116.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_Snow_020518b_3814.256-3816.9.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_Snow_020518b_8978.383-8982.05.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_Davis_Cameron_010325_310.832-313.832.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_Davis_Cameron_011109_1460.871-1463.871.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_Davis_Hannah_020121_1584.895-1587.895.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_Davis_Nate_020015_549.664-552.265.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_Davis_Rebecca_010404_1105.467-1108.467.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_Davis_Rebecca_010501_378.99-381.99.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_Davis_Rebecca_010514_471.863-474.863.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_Davis_Rebecca_010514_504.244-511.244.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_Davis_Rebecca_010514_504.244-511.244.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_Davis_Rebecca_010514_504.244-511.244.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_Davis_Rebecca_010521_571.965-574.965.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_Davis_Rebecca_010424_1758.107-1761.107.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_Davis_Rebecca_010428_1894.278-1897.278.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_Davis_Rebecca_010514_1700.648-1703.648.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_Davis_Rebecca_010524_4422.296-4425.296.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_Davis_Rebecca_010605_4165.592-4167.7.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_Davis_Rebecca_010605_4266.171-4269.171.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_Davis_Rowan_011011_1296.849-1302.849.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_Davis_Rowan_011011_1296.849-1302.849.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_Davis_Rowan_011011_1468.803-1473.803.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_Davis_Rowan_011011_1468.803-1473.803.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_Davis_Rowan_011011_1645.654-1649.654.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_Davis_Rowan_011011_1653.984-1656.984.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_Davis_Rowan_011121_686.531-689.444.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_Davis_Rowan_011011_2596.992-2601.992.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_Davis_Rowan_011011_2596.992-2601.992.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_Davis_Rowan_011011_2944.058-2948.058.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_Davis_Rowan_011011_2944.058-2948.058.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_Davis_Rowan_011011_3438.201-3453.201.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_Davis_Rowan_011011_3438.201-3453.201.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_Davis_Rowan_011011_3438.201-3453.201.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_Davis_Rowan_011011_3438.201-3453.201.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_Davis_Rowan_011011_3438.201-3453.201.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_Weist_Ben_020413_102.844-111.705.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_Weist_Ben_020804_159.624-163.596.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_Weist_Emily_040414_345.088-351.622.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_Braunwald_010522_877.659-878.518.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_Braunwald_010511_609.585-611.037.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_Braunwald_030001_85.365-89.707.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_MacWhinney_020817d_593.511-603.277.wav already exists and will be overwritten on build
# output_file: parsedfiles/car_MacWhinney_030526a_628.991-662.53.wav already exists and will be overwritten on build
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/r0/hwz_y7sd2z3d2289s5jmtv180000gp/T/ipykernel_36645/1801516506.py in <module>
#      27             nofind = nofind + [someutt]
#      28
# ---> 29 print("Unable to find file online: " + nofind)
#      30 print("Unable to find file locally: " + noparse)
#
# TypeError: can only concatenate str (not "list") to str

# %% [markdown]
# # Next up, processing the audio files for input into CNN
#
# First, we check to see how much we've got to work with

# %%
print("Unable to find file online: ")
print(nofind)
print("Unable to find file locally: ")
print(noparse)
# Out:
# Unable to find file online:
# [2414379, 2414415, 2414443, 2414538, 2414644, 2414656, 2414702, 2414738, 2414764, 2414817, 2414976, 2415042, 2415093, 2415103, 2415185, 2415202, 2415226, 2415310, 2415398, 2415555, 2415694, 2415793, 2415831, 2415873, 2416008, 2416058, 2416135, 2416181, 2416250, 2416324, 2416351, 2416376, 2416610, 2416684, 2416786, 2416800, 2416840, 2416850, 2417033, 2417306, 2417320, 2417691, 2417808, 2418243, 2418286, 2418416, 2418448, 2418480, 2418517, 2418534, 2418584, 2418615, 2418629, 2418699, 2418713, 2418806, 2418845, 2418874, 2418921, 2418934, 2419246, 2419273, 2419313, 2419506, 2419563, 2419588, 2419657, 2419690, 2419799, 2419824, 2419874, 2419942, 2420024, 2420036, 2420219, 2420283, 2420511, 2420575, 2420585, 2420612, 2420796, 2420807, 2420819, 2420839, 2420850, 2421074, 2422042, 2422155, 2422236, 2422302, 2422431, 2422493, 2422510, 2422674, 2422690, 2422731, 2422799, 2422811, 2422871, 2422887, 2422894, 2422926, 2422943, 2422988, 2422995, 2423066, 2423097, 2423281, 2423297, 2423303, 2423360, 2423374, 2423379, 2424233, 2424272, 2424332, 2424362, 2424412, 2424507, 2424581, 2424667, 2424705, 2424722, 2424780, 2425001, 2425026, 2425048, 2425148, 2425187, 2425214, 2425274, 2425284, 2425340, 2425358]
# Unable to find file locally:
# []

# %% [markdown]
# Next up, set up 'usedata' to contain all the information about the files we need
#
# Exclude files that
# * don't exist
# * are 10 seconds or longer
# * don't contain any of our target words

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np
from scipy.io import wavfile

# which utterances contain which words?
alldata.loc[:,words] = 0
for word in words:
    alldata.loc[alldata["id"].isin(word2utt[word]), word] = 1

# childes-db list of transcripts is missing some of transcripts available in their list of utterances
alldata.loc[:,"file"] = np.array([trans2file.get(key) for key in alldata["transcript_id"]], dtype='O')
usedata = alldata[alldata["file"].isna() == False]
#this looks stupid but was only thing I could get to work
usedata.loc[:,"file"] = np.array([trans2file.get(key)[0] for key in usedata["transcript_id"]], dtype='O')
usedata.loc[:,"file"] = usedata.apply(lambda x: re.sub(".xml","",x["file"]), axis=1)
usedata.loc[:,"file"] = usedata.apply(lambda x: re.sub('.*Eng-NA/',"",x["file"]), axis=1)
usedata.loc[:,"file"] = usedata.apply(lambda x: re.sub('.*Frogs/',"",x["file"]), axis=1)
usedata.loc[:,"file"] = usedata.apply(lambda x: re.sub('.*Clinical-MOR/',"",x["file"]), axis=1)
usedata.loc[:,"file"] = usedata.apply(lambda x: re.sub("/","_",x["file"]), axis=1)
usedata.loc[:,"file"] = [''.join([str(x[1]["file"]), "_", str(x[1]["media_start"]), "-", str(x[1]["media_end"]), ".wav"]) for x in usedata.iterrows()]
usedata.loc[:,"length"] = usedata["media_end"] - usedata["media_start"]
usedata.loc[:,"tot"] = usedata[words].sum(axis=1)

alltrainingdata = usedata[(usedata["length"]<10) & (usedata["tot"]>0)]

print(alltrainingdata["tot"].value_counts())

print(alltrainingdata[words].sum())

print(alltrainingdata.iloc[0:5])

print("done")
# Out:
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# 1    10268
# 2      253
# 3        5
# Name: tot, dtype: int64
# baby     3983
# daddy    1663
# mommy    2995
# dad       459
# car      1689
# dtype: int64
#             id  transcript_id  media_start  media_end  gloss target_child_sex  \
# 23919  2618441           9852      581.107    585.256  mommy             male
# 42513  2637036           9958      135.516    137.102   baby             male
# 42535  2637058           9958      138.205    139.957   baby             male
# 42600  2637123           9958      151.580    154.082   baby             male
# 43110  2637633           9958      290.901    292.404   baby             male
#
#        target_child_age  baby  daddy  mommy  dad  car  \
# 23919          7.000144     0      0      1    0    0
# 42513         10.000205     1      0      0    0    0
# 42535         10.000205     1      0      0    0    0
# 42600         10.000205     1      0      0    0    0
# 43110         10.000205     1      0      0    0    0
#
#                                              file  length  tot
# 23919  NewmanRatner_07_7013VD_581.107-585.256.wav   4.149    1
# 42513  NewmanRatner_10_6314AK_135.516-137.102.wav   1.586    1
# 42535  NewmanRatner_10_6314AK_138.205-139.957.wav   1.752    1
# 42600   NewmanRatner_10_6314AK_151.58-154.082.wav   2.502    1
# 43110  NewmanRatner_10_6314AK_290.901-292.404.wav   1.503    1
# done
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/pandas/core/indexing.py:1667: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = value

# %% [markdown]
# Now, read in the data
#
# Note: It seems that Eng-NA/McCune/Alice/011000.mp4 should definitely exist but is not on the server.

# %%
all_wave = {}
for readfile in alltrainingdata["file"]:
    try:
        samples, sample_rate = librosa.load('parsedfiles/' + readfile, sr = 16000)
    except Exception as nofind:
        print("Strangely cannot find file: " + readfile)
    all_wave[readfile] = samples

print(len(all_wave))
print(len(usedata["id"]))
# Out:
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Strangely cannot find file: McCune_Alice_010900_21.523-28.36.wav
# Strangely cannot find file: McCune_Alice_010900_34.253-39.241.wav
# Strangely cannot find file: McCune_Alice_010900_52.205-54.106.wav
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Strangely cannot find file: McCune_Alice_010900_64.628-67.766.wav
# Strangely cannot find file: McCune_Alice_010900_105.291-109.401.wav
# Strangely cannot find file: McCune_Alice_010900_150.633-155.401.wav
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Strangely cannot find file: McCune_Alice_010900_159.195-160.638.wav
# Strangely cannot find file: McCune_Alice_010900_182.123-187.78.wav
# Strangely cannot find file: McCune_Alice_010900_198.075-206.621.wav
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Strangely cannot find file: McCune_Alice_010900_208.896-210.798.wav
# Strangely cannot find file: McCune_Alice_010900_228.41-231.156.wav
# Strangely cannot find file: McCune_Alice_010900_290.055-295.441.wav
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Strangely cannot find file: McCune_Alice_010900_312.686-315.683.wav
# Strangely cannot find file: McCune_Alice_010900_335.53-339.488.wav
# Strangely cannot find file: McCune_Alice_010900_341.116-343.893.wav
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Strangely cannot find file: McCune_Alice_010900_384.163-392.11.wav
# Strangely cannot find file: McCune_Alice_010900_396.511-401.806.wav
# Strangely cannot find file: McCune_Alice_010900_408.74-413.785.wav
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Strangely cannot find file: McCune_Alice_010900_455.113-460.281.wav
# Strangely cannot find file: McCune_Alice_010900_461.371-464.446.wav
# Strangely cannot find file: McCune_Alice_010900_480.26-483.33.wav
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Strangely cannot find file: McCune_Alice_010900_500.998-507.561.wav
# Strangely cannot find file: McCune_Alice_010900_523.563-529.8.wav
# Strangely cannot find file: McCune_Alice_010900_534.395-543.675.wav
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Strangely cannot find file: McCune_Alice_010900_547.073-554.478.wav
# Strangely cannot find file: McCune_Alice_010900_578.428-581.891.wav
# Strangely cannot find file: McCune_Alice_010900_588.586-590.671.wav
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Strangely cannot find file: McCune_Alice_010900_605.285-612.281.wav
# Strangely cannot find file: McCune_Alice_010900_645.586-650.081.wav
# Strangely cannot find file: McCune_Alice_010900_650.081-653.188.wav
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Strangely cannot find file: McCune_Alice_010900_653.188-657.088.wav
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Strangely cannot find file: McCune_Alice_010900_658.056-664.55.wav
# Strangely cannot find file: McCune_Alice_010900_666.971-670.145.wav
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Strangely cannot find file: McCune_Alice_010900_671.135-676.388.wav
# Strangely cannot find file: McCune_Alice_010900_680.085-684.838.wav
# Strangely cannot find file: McCune_Alice_010900_727.44-732.533.wav
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Strangely cannot find file: McCune_Alice_010900_732.533-736.873.wav
# Strangely cannot find file: McCune_Alice_010900_752.51-761.793.wav
# Strangely cannot find file: McCune_Alice_010900_783.476-787.891.wav
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Strangely cannot find file: McCune_Alice_010900_787.891-794.831.wav
# Strangely cannot find file: McCune_Alice_010900_798.995-800.835.wav
# Strangely cannot find file: McCune_Alice_010900_800.835-802.886.wav
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Strangely cannot find file: McCune_Alice_010900_802.886-804.173.wav
# Strangely cannot find file: McCune_Alice_010900_839.315-840.478.wav
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Strangely cannot find file: McCune_Alice_010900_866.605-871.805.wav
# Strangely cannot find file: McCune_Alice_010900_871.805-875.496.wav
# Strangely cannot find file: McCune_Alice_010900_927.668-935.018.wav
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Strangely cannot find file: McCune_Alice_010900_955.296-958.995.wav
# Strangely cannot find file: McCune_Alice_010900_1026.546-1030.505.wav
# Strangely cannot find file: McCune_Alice_010900_1038.541-1043.265.wav
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Strangely cannot find file: McCune_Alice_010900_1058.148-1063.138.wav
# Strangely cannot find file: McCune_Alice_010900_1067.706-1071.673.wav
# Strangely cannot find file: McCune_Alice_010900_1072.315-1076.143.wav
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Strangely cannot find file: McCune_Alice_010900_1080.76-1086.693.wav
# Strangely cannot find file: McCune_Alice_010900_1086.693-1091.411.wav
# Strangely cannot find file: McCune_Alice_010900_1094.563-1103.636.wav
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Strangely cannot find file: McCune_Alice_010900_1104.921-1109.175.wav
# Strangely cannot find file: McCune_Alice_010900_1109.175-1114.406.wav
# Strangely cannot find file: McCune_Alice_010900_1132.185-1135.655.wav
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Strangely cannot find file: McCune_Alice_010900_1135.655-1144.465.wav
# Strangely cannot find file: McCune_Alice_010900_1165.418-1167.608.wav
# Strangely cannot find file: McCune_Alice_010900_1169.785-1175.475.wav
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Strangely cannot find file: McCune_Alice_010900_1175.475-1179.68.wav
# Strangely cannot find file: McCune_Alice_010900_1179.68-1183.938.wav
# Strangely cannot find file: McCune_Alice_010900_1185.648-1187.136.wav
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Strangely cannot find file: McCune_Alice_010900_1187.136-1189.881.wav
# Strangely cannot find file: McCune_Alice_010900_1270.901-1274.948.wav
# Strangely cannot find file: McCune_Alice_010900_1275.641-1278.415.wav
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Strangely cannot find file: McCune_Alice_010900_1279.693-1284.991.wav
# Strangely cannot find file: McCune_Alice_010900_1308.046-1313.976.wav
# Strangely cannot find file: McCune_Alice_010900_1324.751-1330.253.wav
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Strangely cannot find file: McCune_Alice_010900_1334.2-1336.886.wav
# Strangely cannot find file: McCune_Alice_010900_1345.766-1350.436.wav
# Strangely cannot find file: McCune_Alice_010900_1350.436-1356.15.wav
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Strangely cannot find file: McCune_Alice_010900_1356.928-1361.701.wav
# Strangely cannot find file: McCune_Alice_010900_1365.63-1368.851.wav
# Strangely cannot find file: McCune_Alice_010900_1392.133-1398.433.wav
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Strangely cannot find file: McCune_Alice_010900_1417.111-1424.336.wav
# Strangely cannot find file: McCune_Alice_010900_1426.751-1432.761.wav
# Strangely cannot find file: McCune_Alice_010900_1439.411-1443.158.wav
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Strangely cannot find file: McCune_Alice_010900_1451.231-1455.218.wav
# Strangely cannot find file: McCune_Alice_010900_1455.218-1461.763.wav
# Strangely cannot find file: McCune_Alice_010900_1524.411-1528.476.wav
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Strangely cannot find file: McCune_Alice_010900_1539.528-1541.196.wav
# Strangely cannot find file: McCune_Alice_010900_1597.69-1601.546.wav
# Strangely cannot find file: McCune_Alice_010900_1609.775-1614.56.wav
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Strangely cannot find file: McCune_Alice_010900_1614.56-1620.321.wav
# Strangely cannot find file: McCune_Alice_010900_1651.876-1661.353.wav
# Strangely cannot find file: McCune_Alice_010900_1664.415-1673.411.wav
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Strangely cannot find file: McCune_Alice_010900_1674.088-1682.573.wav
# Strangely cannot find file: McCune_Alice_010900_1685.9-1691.16.wav
# Strangely cannot find file: McCune_Alice_010900_1691.16-1693.755.wav
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Strangely cannot find file: McCune_Alice_010900_1698.93-1704.196.wav
# Strangely cannot find file: McCune_Alice_010900_1717.981-1720.775.wav
# Strangely cannot find file: McCune_Alice_010900_1724.053-1727.356.wav
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Strangely cannot find file: McCune_Alice_010900_1727.356-1731.808.wav
# Strangely cannot find file: McCune_Alice_010900_1784.015-1789.03.wav
# Strangely cannot find file: McCune_Alice_010900_1816.481-1823.188.wav
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Strangely cannot find file: McCune_Alice_010900_1845.425-1850.508.wav
# Strangely cannot find file: McCune_Alice_010900_1861.746-1864.328.wav
# Strangely cannot find file: McCune_Alice_010900_1889.363-1895.215.wav
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Strangely cannot find file: McCune_Alice_010900_1930.768-1935.745.wav
# Strangely cannot find file: McCune_Alice_010900_1944.991-1948.511.wav
# Strangely cannot find file: McCune_Alice_010900_1949.106-1953.476.wav
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Strangely cannot find file: McCune_Alice_010900_1977.033-1980.171.wav
# Strangely cannot find file: McCune_Alice_010900_1981.25-1983.275.wav
# Strangely cannot find file: McCune_Alice_010900_1997.066-1999.84.wav
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Strangely cannot find file: McCune_Alice_010900_2021.183-2024.345.wav
# Strangely cannot find file: McCune_Alice_010900_2024.345-2028.151.wav
# Strangely cannot find file: McCune_Alice_010900_2054.796-2058.468.wav
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Strangely cannot find file: McCune_Alice_010900_2083.986-2089.141.wav
# Strangely cannot find file: McCune_Alice_010900_2091.739-2097.265.wav
# Strangely cannot find file: McCune_Alice_010900_2097.265-2100.24.wav
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Strangely cannot find file: McCune_Alice_010900_2127.92-2132.858.wav
# Strangely cannot find file: McCune_Alice_010900_2132.858-2136.718.wav
# Strangely cannot find file: McCune_Alice_010900_2136.718-2138.74.wav
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Strangely cannot find file: McCune_Alice_010900_2141.043-2149.235.wav
# Strangely cannot find file: McCune_Alice_010900_2154.745-2158.79.wav
# Strangely cannot find file: McCune_Alice_010900_2160.638-2162.38.wav
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Strangely cannot find file: McCune_Alice_010900_2177.501-2187.236.wav
# Strangely cannot find file: McCune_Alice_010900_2258.818-2266.433.wav
# Strangely cannot find file: McCune_Alice_010900_2267.905-2269.551.wav
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Strangely cannot find file: McCune_Alice_010900_2269.551-2274.713.wav
# Strangely cannot find file: McCune_Alice_010900_2301.455-2305.555.wav
# Strangely cannot find file: McCune_Alice_010900_2306.361-2313.201.wav
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Strangely cannot find file: McCune_Alice_010900_2313.201-2318.685.wav
# Strangely cannot find file: McCune_Alice_010900_2353.386-2355.663.wav
# Strangely cannot find file: McCune_Alice_010900_2357.836-2360.035.wav
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Strangely cannot find file: McCune_Alice_010900_2378.526-2380.885.wav
# Strangely cannot find file: McCune_Alice_010900_2417.34-2423.185.wav
# Strangely cannot find file: McCune_Alice_010900_2444.928-2453.063.wav
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Strangely cannot find file: McCune_Alice_010900_2458.191-2461.96.wav
# Strangely cannot find file: McCune_Alice_010900_2473.835-2480.426.wav
# Strangely cannot find file: McCune_Alice_010900_2483.801-2490.226.wav
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Strangely cannot find file: McCune_Alice_010900_2494.521-2497.48.wav
# Strangely cannot find file: McCune_Alice_010900_2504.353-2507.713.wav
# Strangely cannot find file: McCune_Alice_010900_2566.765-2568.365.wav
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Strangely cannot find file: McCune_Alice_010900_2572.516-2573.088.wav
# Strangely cannot find file: McCune_Alice_010900_2575.271-2576.426.wav
# Strangely cannot find file: McCune_Alice_010900_2607.713-2613.73.wav
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Strangely cannot find file: McCune_Alice_010900_2619.525-2621.946.wav
# Strangely cannot find file: McCune_Alice_010900_2633.623-2639.213.wav
# Strangely cannot find file: McCune_Alice_010900_2639.213-2644.943.wav
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Strangely cannot find file: McCune_Alice_010900_2648.473-2656.386.wav
# Strangely cannot find file: McCune_Alice_010900_2657.705-2659.826.wav
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Users/jkhartshorne/Envs/2021_9_worddetection/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Strangely cannot find file: MacWhinney_021001a_416.151-420.132.wav
# Strangely cannot find file: MacWhinney_021001a_1112.283-1115.609.wav
# 10526
# 10526

# %%
import keras

temp = keras.preprocessing.sequence.pad_sequences(all_wave, maxlen=159920)
print(np.shape(temp))

# %%
alltrainingdata.describe()
# Out:
#                  id  transcript_id   media_start     media_end  \
# count  1.052600e+04   10526.000000  10526.000000  10526.000000
# mean   1.047773e+07   26877.227817   1602.227642   1605.459361
# std    6.951607e+06   15767.110287   2017.852500   2017.967001
# min    3.248250e+05    3350.000000      0.778000      1.880000
# 25%    2.435630e+06    9271.000000    443.064500    446.126750
# 50%    1.427699e+07   32441.000000    959.753500    962.571500
# 75%    1.675449e+07   42124.250000   1935.116750   1938.517000
# max    1.725424e+07   43674.000000  16257.374000  16261.229000
#
#        target_child_age          baby         daddy         mommy  \
# count      10526.000000  10526.000000  10526.000000  10526.000000
# mean          28.895044      0.378396      0.157990      0.284534
# std           10.093961      0.485010      0.364749      0.451213
# min            7.000144      0.000000      0.000000      0.000000
# 25%           21.000431      0.000000      0.000000      0.000000
# 50%           28.493398      0.000000      0.000000      0.000000
# 75%           34.000698      1.000000      0.000000      1.000000
# max           69.001417      1.000000      1.000000      1.000000
#
#                 dad           car        length           tot
# count  10526.000000  10526.000000  10526.000000  10526.000000
# mean       0.043606      0.160460      3.231718      1.024986
# std        0.204227      0.367049      1.896246      0.159103
# min        0.000000      0.000000      0.001000      1.000000
# 25%        0.000000      0.000000      1.864250      1.000000
# 50%        0.000000      0.000000      3.000000      1.000000
# 75%        0.000000      0.000000      4.066500      1.000000
# max        1.000000      1.000000      9.995000      3.000000
